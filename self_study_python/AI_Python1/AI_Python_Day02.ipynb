# %% [markdown]
# # 2일차
# ## day 02
# ## 0.복습
# ### 프로그래밍 언어
# - : 사람과 컴퓨터가 소통하기 위해 사용하는 언어
# ### 파이썬
# ### 고급언어
# - AI, 빅데이터 분석 분야에 가장 많이 사용되는 프로그래밍 언어
# ### 파이썬 기본 문법
# ### print() : 출력함수
# ### () 소괄호 안에 있는 값을 출력
# ### 출력 함수의 2가지 옵션
# - end 옵션 : 출력할 내용의 마지막 설정(기본 값 : \n)
# - sep 옵션 : 출력 요소 사이마다 넣을 내용 설정
# ### 따옴표('', "")
# ### : 문자열을 표현할 때 사용
# - ex) "짱구", "abc"
# ### 변수
# - : 재사용할 값을 저장하기 위한 저장공간
# ### 변수의 생성
# ### : 변수명 = 값
# - =(대입 연산자) : 오른쪽의 값을 왼쪽의 저장공간에 대입(저장)
# - ex) a = 10
# ### 변수의 사용
# - : 저장할 값을 사용할 곳에 변수명을 작성
# - ex) print(a) # a에 저장된 값을 출력
# ### 변수
# ### 변수에 저장된 값 수정
# - 변수명(기존의 변수) = 수정할 값
# ### 변수 삭제
# - 변수를 삭제하기 위해서는 del이라는 키워드 사용
# ### del 변수명
# ### 변수명 작성시 주의사항
# ### (1) 띄어쓰기가 불가능하다
# ### my age = 20 (x)

# %%
myage = 20 (o)
my_age = 20 (o) 스네이크 표기법(소문자로 구성, 단어가 바뀔때 _로 연결)
myAge = 20 (o) 카멜표기법(소문자로 시작, 단어가 바뀔때 첫문자를 대문자)
MyAge = 20 (o) 파스칼 표기법(클래스명을 만들 때 주로 사용)

# %% [markdown]
# - (2) 특수문자 사용이 불가능하다(단, _언더바만 사용 가능)
# ### !@# = 10 (x)
# ### (3) 숫자로 시작 불가능하다
# ### 1num = 10 (x)

# %%
num1 = 10 (o)
n1um = 10 (o)

# %% [markdown]
# - (4) 키워드(예약어)는 사용 불가능하다
# - 키워드 : 문법으로 사용되고 있는 단어
# - ex) if, class, for, ...
# - (5) 웬만하면 의미 있는 단어를 사용하자
# - ex) 나이 : age, mys_age, ...
# - 이름 : name, mys_age, ...
# - 숫자 : number, num, num1, ...
# ### (6) 웬만하면 소문자로 시작
# ### 기본 자료형
# - 자료형(data type) : 값(데이터)의 종류
# ### 자료형
# - ==========================================================
# - 정수형(int)	양의 정수, 음의 정수, 0
# - 실수형(float) 소수점이 있는 숫자
# - 논리형(bool)  True(참), False(거짓)
# - 문자열(str)   '', "" 따옴표로 감싸진 값
# - 형변환(type casting)
# ### : 자료형을 다른 자료형으로 변환
# ### 정수형 형변환 함수 : int()
# - 다른 자료형의 값을 정수형으로 변환
# - ex) int(1.99) => 1
# - 실수형 형변환 함수 : float()
# - 다른 자료형의 값을 실수형으로 변환
# - ex) float(3) => 3.0
# - 논리형 형변환 함수 : bool()
# - False로 변환 : 0, 0.0, "", [], {}, ()
# - True로 변환 : False로 변환되는 것들을 제외한 전부
# ### 문자열 형변환 함수 : str()
# - 다른 자료형의 값을 문자열로 형변환
# - ex) str(10) = > "10"
# ### 시퀀스 자료형
# ### 값이 연속적으로 이어진 자료형
# - 데이터가 순차적으로 이어진 자료형
# - 문자열(str), 리스트(list), 튜플(tuple), ...
# - 시퀀스 자료형 안에 있는 각 데이터에는 고유 번호가 있음
# ### => 인덱스 번호
# - 인덱스 번호 : 문자열을 구성하는 모든 문자에 부여된 고유번호
# ### 시작 번호는 앞에서부터 0
# - 마이너스 인덱스의 시작번호는 뒤에서부터 -1
# ### 인덱싱(indexing) :
# - 특정 문자 1개를 추출하고자 할때 사용
# ### 변수명[인덱스 번호]
# ### 슬라이싱(slicing)
# - 문자열에서 한 문자 이상으로 구성된 단어나 문자를 추출할 때 사용
# - 변수명[시작 idx : 종료 idx : 간격]
# - 시작 idx : 슬라이싱 첫번째 인덱스 번호
# - 종료 idx : 종료 idx 이전까지
# - 간격 : 슬라이싱 간격(기본값 1)
# ### 시퀀스 연산자
# - : 시퀀스 자료형에서 사용할 수 있는 연산
# ### (1) + : 연결
# ### 숫자 + 숫자 => 덧셈
# ### 문자열 + 문자열 => 연결
# ### (2) * : 반복
# ### 숫자 * 숫자 => 곱셈
# ### 문자열 * int => 반복
# ### 변수

# %%
# 변수에 저장된 값 수정

a = 10
print(a)

a = 20 # a에 저장된 값을 20으로 수정
print(a)

a = 100
b = 200

a = b # b에 저장된 값 (200)을 a라는 변수에 저장, a = 200
# = : 오른쪽의 값을 왼쪽의 저장공간에 저장
print(a) # 200

# 변수 삭제
# : del 변수명

x = 10 # x라는 변수에 10을 저장
print(x)

del x # x라는 변수 삭제
print(x) # name 'x' is not defined => x라는 변수는 삭제되었으므로 사용 불가

# %% [markdown]
# ### 변수명 작성 주의사항

# %%
# 1) 띄어쓰기 불가능
# my age = 20

my_age = 20 # 스네이크 표기법, 팟홀 표기법
myAge = 20 # 카멜 표기법
MyAge = 20 # 파스칼 표기법(클래스 작성)

# 2) 특수문자 사용 불가(_언더바 제외)
# @! = 10

# 3) 숫자로 시작 불가능
# 1num = 10
num1 = 10
n1um = 10

# 4) 키워드 사용 불가능
# if = 10

# %% [markdown]
# ### 기본 자료형

# %%
# 1) 정수형(int)
print(10, type(10))

# 2) 실수형(float)
print(3.14, type(3.14))
print(1.0, type(1.0)) # 소수점이 붙으면 무조건 실수

# 3) 논리형(bool) : True, False
print(True, type(True))
print(False, type(False))

# 4) 문자열(str)
print("Hello", type("Hello"))
print("10", type("10")) # 따옴표가 붙어 있으면 문자열
print("10 + 20", type("10 + 20"))
print("10" + "20") # 문자열 + 문자열 => 연결

# %% [markdown]
# ### 형변환

# %%
# 1) 정수형 형변환 : int()

# (1) 실수 => 정수
print(15.19, type(15.19))
print(int(15.19), type(int(15.19))) # 15.19 => 15 (소수부는 버림)

# (2) 문자열 => 정수
print("15", type("15"))
print(int("15"), type(int("15"))) # "15" => 15

# print(int("15.19")) # 문자열 실수는 정수로 형변환 불가능!
print(float("15.19"), type(float("15.19"))) # "15.19" => 15.19
print(int(float("15.19"))) # "15.19" => 15.19 => 15

# print(int("가")) # 문자열 자료형을 정수로 변환할 때는 변환 가능한 값을 넣어줘야함

# (3) 논리형 => 정수
#  True => 1
# False => 0
print(int(True)) # 1
print(int(False)) # 0

print(True + 10) # 1 + 10
print(False * 10) # 0 * 10

# 2) 실수형 형변환 : float()

# (1) 정수 => 실수
print(float(5), type(float(5))) # 5 => 5.0

#  (2) 문자열 => 실수
print(float("3.14"), type(float("3.14"))) # "3.14" => 3.14
print(float("5"), type(float("5"))) # 정수형 문자열은 실수로 형변환 가능

# (3) 논리형 => 실수
print(float(True), type(float(True))) # True => 1.0
print(float(False), type(float(False))) # False => 0.0

# 3) 논리형 형변환 : bool()

print(bool(0), type(bool(0)))
print(bool(123), type(bool(123))) # 0, 0.0을 제외한 숫자는 모두 True로 변환됨
print(bool(""), type(bool(""))) # 빈문자열 => False
print(bool([]), type(bool([]))) # 빈괄호 => False

# 4) 문자열 형변환 : str()

print(str(10), type(str(10))) # 10 => "10"
print(str(3.14), type(str(3.14))) # 3.14 => "3.14"
print(str(True), type(str(True))) # True => "True"

# %% [markdown]
# ### 시퀀스 자료형

# %%
#  1) 인덱싱

# idx   01234
data = "hello"
#       -54321

print(data, type(data))
print(data[0], type(data[0])) # h
print(data[-5]) # h

# hlo, 홀수번째 문자들 추출
print(data[0], data[2], data[4]) # 인덱스 사용
print(data[-5] + data[-3] + data[-1]) # 마이너스 인덱스 사용

# <실습> hello를 역순으로 출력 => olleh
# 인덱스 사용
print(data[4] + data[3] + data[2] + data[1] + data[0])
# 마이너스 인덱스 사용
print(data[-1] + data[-2] + data[-3] + data[-4] + data[-5])

# 2) 슬라이싱
# 변수명[시작:종료:간격]
#       01234
data = "hello"
#      -54321

print(data[0:3:1]) # idx 0부터 2까지 1씩 가격으로 슬라이싱
print(data[0:3]) # 간격의 기본값은 1
print(data[:3]) # 0번 인덱스 번호 생략 => 첫문자부터 자를 경우
print(data[0:5:2]) # idx 0부터 4까지 2씩 간격으로 슬라이싱
print(data[:5:2])
print(data[::2]) # 마지막까지 자를 경우 => 종료 인덱스 생략 가능

# +) 간격에 음수 값을 넣으면 뒤에서부터 슬라이싱
print(data[::-1]) # 처음부터 끝까지 뒤에서부터 1씩(-1) 슬라이싱

# 3) 시퀀스 연산자

# + : 문자열 연결
data1 = "hello"
data2 = "python"

print(data1 + data2) # 문자열 + 문자열
# print(data1 + 10) # 문자열 + 다른 자료형 => 오류 발생!

# * : 문자열 반복
print("hello" * 3) # 'hello' 3번 반복
# print("hello" * 3.5)
# print("hello" * 3.0) # 3.0도 float타입!

# %% [markdown]
# ## 과제
# - 문제1) hello python을 출력하기(변수명은 str1로 설정)

# %%
str1 = "hello python"

print(str1 * 3)

str1 = "hello python"

print(str1[6] + str1[7])
print(str1[-6] + str1[-5])

str1 = "hello python"

print(str1[0] + str1[3] + str1[4] + str1[6] +str1[8] + str1[10])
print(str1[-12] + str1[-10] + str1[-8] + str1[-6] +str1[-4] + str1[-2])

# %% [markdown]
# - 문제2) 변수에 저장된 값 수정하기 num 이란는 변수에 10을 저장한 후
# - 5를 더한 값으로 변수에 저장된 값 수정하기
# - <출력예시> num에 저장된 값 : 10 ==== 수정 후의 값 ==== 수정된 num의 값 : 15

# %%
num = 10
num = num + 5
print(num)
